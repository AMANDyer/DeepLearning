# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/jobs - jobs.csv")

# %%
df.head()
# Out:
#         Company Name                Location                    Job Title
# 0  Commonwealth Bank  Sydney Area, Australia          Portfolio Executive
# 1  Commonwealth Bank  Sydney Area, Australia  Solution Delivery Executive
# 2            CommSec  Sydney Area, Australia              Project Manager
# 3  Commonwealth Bank  Sydney Area, Australia              Project Manager
# 4             PayPal  Sydney Area, Australia     Senior Marketing Manager

# %%
df.shape
# Out:
# (39537, 3)

# %%
df=df.sample(5000,ignore_index=True)

# %%
import string

# %%
panch=string.punctuation
panch
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_panch(text):
  mylist=[]
  for i in text.split():
    if i not in panch:
      mylist.append(i)
    return " ".join(mylist)

# %%
df["Job Title"]=df['Job Title'].apply(remove_panch)
df['Location']=df['Location'].apply(remove_panch)

# %%
df['Company Name']=df['Company Name'].astype(str)

# %%
df['Company Name']=df['Company Name'].apply(remove_panch)

# %%
df['Content']=df.apply(lambda x:" ".join(x.dropna().astype(str)),axis=1)

# %%
df
# Out:
#      Company Name    Location    Job Title                           Content
# 0         Telstra  Townsville      Project        Telstra Townsville Project
# 1      University     Sydney,    Sessional      University Sydney, Sessional
# 2       Gestetner       North    Marketing         Gestetner North Marketing
# 3         Meriton      Sydney     Graduate           Meriton Sydney Graduate
# 4      University   Brisbane,  Information  University Brisbane, Information
# ...           ...         ...          ...                               ...
# 4995           CA  Melbourne,       Senior              CA Melbourne, Senior
# 4996          IBM    Brisbane        Brand                IBM Brisbane Brand
# 4997       Thiess     Sydney,         Site               Thiess Sydney, Site
# 4998        JASCO  Melbourne,      General          JASCO Melbourne, General
# 4999           SA    Keswick,      Network               SA Keswick, Network
#
# [5000 rows x 4 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features= 5000)

# %%
metrics=cv.fit_transform(df['Content']).toarray()

# %%
metrics.shape
# Out:
# (5000, 3328)

# %%
similarity=cosine_similarity(metrics)

# %%
def recommend(Job_Title):
  index=df[df['Job Title']==Job_Title].index[0]
  distances=sorted(list(enumerate(similarity[index])),reverse=True,key=lambda x:x[1])
  new_index=[i[0] for i in distances[1:11]]
  return df.iloc[new_index, :-1]

# %%
df.sample(5)
# Out:
#      Company Name   Location Job Title                        Content
# 4220    Schneider   Adelaide  Business    Schneider Adelaide Business
# 1689   McCullough  Brisbane,  Research  McCullough Brisbane, Research
# 2279           BG  Brisbane,     Chief             BG Brisbane, Chief
# 4063           St    Sydney,  Learning            St Sydney, Learning
# 127        L.E.K.    Sydney,  Managing        L.E.K. Sydney, Managing

# %%
recommend('Business')
# Out:
#     Company Name Location Job Title
# 217       Credit  Sydney,  Business
# 334      Westpac   Sydney  Business
# 341          MBF  Sydney,  Business
# 564   Inspection  Sydney,  Business
# 605      Halifax  Sydney,  Business
# 702     European  Sydney,  Business
# 789        Great   Sydney  Business
# 810      Cellcom  Sydney,  Business
# 869    Macquarie  Sydney,  Business
# 922          AMP  Sydney,  Business
